# %% [markdown]
# ## 实验1
#
# 首先，加载rpy2，使得R和Pyhton可以同时用

# %%
# %load_ext rpy2.ipython

# %% [markdown]
# ## 数据集
# 准备mnist数据，将其归一化和向量化

# %%
from keras.datasets import mnist
import numpy as np
(x_train, x_train_lab), (x_test, x_test_lab) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

print(x_train.shape)
print(x_test.shape)
# Out:
# Using TensorFlow backend.
# /home/ncclab/anaconda3/envs/iccv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ncclab/anaconda3/envs/iccv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ncclab/anaconda3/envs/iccv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ncclab/anaconda3/envs/iccv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ncclab/anaconda3/envs/iccv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ncclab/anaconda3/envs/iccv/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/ncclab/anaconda3/envs/iccv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ncclab/anaconda3/envs/iccv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ncclab/anaconda3/envs/iccv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ncclab/anaconda3/envs/iccv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ncclab/anaconda3/envs/iccv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ncclab/anaconda3/envs/iccv/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (60000, 784)
# (10000, 784)

# %% [markdown]
# x_train.shape表示训练数据集的shape，其中x_train.shape[0]=60000表示图片的数量·；x_train.shape[0]=784表示图片的维度大小。 x_test.shape 表示测试集的shape，意义同理训练数据集。

# %% [markdown]
# ## DAE
#
# 首先，先建立一个全连接（dense）的编码器和解码器。参数e_dim=2表示中间的隐藏层是2维，,L1=0表示L1正则的权重。

# %%
from keras.layers import Input, Dense
from keras.models import Model
from keras import regularizers

def dense_autoencoder(e_dim=2,L1=0):
    # this is the size of our encoded representations
    encoding_dim = e_dim  # e_dim floats -> compression of factor 784/e_dim, assuming the input is 784 floats
    
    # this is our input placeholder
    input_img = Input(shape=(784,))
    # "encoded" is the encoded representation of the input
    encod_1 = Dense(392, activation='relu',activity_regularizer=regularizers.l1(L1))(input_img)
    encoded = Dense(encoding_dim, activation='relu')(encod_1)
    # "decoded" is the lossy reconstruction of the input
    decod_1 = Dense(392, activation='relu',activity_regularizer=regularizers.l1(L1))(encoded)
    decoded = Dense(784, activation='sigmoid')(decod_1)
    
    # this model maps an input to its reconstruction
    autoencoder = Model(input=input_img, output=decoded)
    
    # this model maps an input to its encoded representation
    encoder = Model(input=input_img, output=encoded)
    
    # create a placeholder for an encoded (32-dimensional) input
    encoded_input = Input(shape=(encoding_dim,))
    # retrieve the last layer of the autoencoder model
    decoder_layer = autoencoder.layers[-2]
    # create the decoder model
    decoder = Model(input=encoded_input, output=decoder_layer(encoded_input))
    return autoencoder, encoder, decoder

# %% [markdown]
# 下面我们训练dense全连接接自编码器，其中e_dim=2,L1=0。这里使用逐像素的交叉熵作为损失函数，优化器为adam

# %%
from keras import optimizers
dense_ae, dense_en, dense_de = dense_autoencoder(e_dim=2,L1=0)
opt = optimizers.Adam(lr=0.001)
dense_ae.compile(optimizer=opt, loss='binary_crossentropy')
dense_ae.fit(x_train, x_train,
                nb_epoch=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# WARNING:tensorflow:From /home/ncclab/anaconda3/envs/iccv/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:71: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/ncclab/anaconda3/envs/iccv/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:514: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/ncclab/anaconda3/envs/iccv/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4076: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/ncclab/anaconda3/envs/iccv/lib/python3.7/site-packages/keras/optimizers.py:757: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /home/ncclab/anaconda3/envs/iccv/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3294: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /home/ncclab/anaconda3/envs/iccv/lib/python3.7/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/ncclab/anaconda3/envs/iccv/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:983: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# /home/ncclab/anaconda3/envs/iccv/lib/python3.7/site-packages/ipykernel_launcher.py:19: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# /home/ncclab/anaconda3/envs/iccv/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# /home/ncclab/anaconda3/envs/iccv/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# /home/ncclab/anaconda3/envs/iccv/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   if __name__ == '__main__':
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.2719 - val_loss: 0.2313
# Epoch 2/50
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.2253 - val_loss: 0.2185
# Epoch 3/50
# 60000/60000 [==============================] - 3s 51us/step - loss: 0.2158 - val_loss: 0.2117
# Epoch 4/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.2104 - val_loss: 0.2079
# Epoch 5/50
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.2069 - val_loss: 0.2048
# Epoch 6/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.2037 - val_loss: 0.2017
# Epoch 7/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.2007 - val_loss: 0.1992
# Epoch 8/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1982 - val_loss: 0.1970
# Epoch 9/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1962 - val_loss: 0.1953
# Epoch 10/50
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.1945 - val_loss: 0.1940
# Epoch 11/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1930 - val_loss: 0.1928
# Epoch 12/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1917 - val_loss: 0.1916
# Epoch 13/50
# 60000/60000 [==============================] - 3s 51us/step - loss: 0.1907 - val_loss: 0.1907
# Epoch 14/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1897 - val_loss: 0.1899
# Epoch 15/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1889 - val_loss: 0.1891
# Epoch 16/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1882 - val_loss: 0.1884
# Epoch 17/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1876 - val_loss: 0.1879
# Epoch 18/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1871 - val_loss: 0.1876
# Epoch 19/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1865 - val_loss: 0.1870
# Epoch 20/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1860 - val_loss: 0.1866
# Epoch 21/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1856 - val_loss: 0.1862
# Epoch 22/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1852 - val_loss: 0.1860
# Epoch 23/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1848 - val_loss: 0.1860
# Epoch 24/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1845 - val_loss: 0.1857
# Epoch 25/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1841 - val_loss: 0.1855
# Epoch 26/50
# 60000/60000 [==============================] - 3s 51us/step - loss: 0.1839 - val_loss: 0.1852
# Epoch 27/50
# 60000/60000 [==============================] - 3s 51us/step - loss: 0.1835 - val_loss: 0.1847
# Epoch 28/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1833 - val_loss: 0.1845
# Epoch 29/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1830 - val_loss: 0.1845
# Epoch 30/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1827 - val_loss: 0.1841
# Epoch 31/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1824 - val_loss: 0.1840
# Epoch 32/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1822 - val_loss: 0.1839
# Epoch 33/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1820 - val_loss: 0.1840
# Epoch 34/50
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.1817 - val_loss: 0.1839
# Epoch 35/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1815 - val_loss: 0.1834
# Epoch 36/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1813 - val_loss: 0.1833
# Epoch 37/50
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.1810 - val_loss: 0.1834
# Epoch 38/50
# 60000/60000 [==============================] - 3s 51us/step - loss: 0.1808 - val_loss: 0.1830
# Epoch 39/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1806 - val_loss: 0.1830
# Epoch 40/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1804 - val_loss: 0.1828
# Epoch 41/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1802 - val_loss: 0.1826
# Epoch 42/50
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.1800 - val_loss: 0.1828
# Epoch 43/50
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.1798 - val_loss: 0.1822
# Epoch 44/50
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.1796 - val_loss: 0.1826
# Epoch 45/50
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.1794 - val_loss: 0.1822
# Epoch 46/50
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.1792 - val_loss: 0.1819
# Epoch 47/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1791 - val_loss: 0.1821
# Epoch 48/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1789 - val_loss: 0.1817
# Epoch 49/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1788 - val_loss: 0.1819
# Epoch 50/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1785 - val_loss: 0.1820

# %% [markdown]
# 模型训练完成之后，我们提取中间的隐藏层的特征。

# %%
import numpy as np
features_dae = dense_en.predict(x_test[0:10000:1])
features_lab = []
lab = ['zero','one','two','three','four','five','six','seven','eight','nine']
for i in range(x_test_lab.shape[0]):
    for j in range(10):
        if x_test_lab[i]==j:
            features_lab.append(lab[j])
        
features_dae = np.transpose(features_dae,(1,0))
print(features_dae.shape)
features_dae_1 =  features_dae[0].reshape(features_dae.shape[1],1)
features_dae_2 =  features_dae[1].reshape(features_dae.shape[1],1)
features_lab   =  np.array(features_lab).reshape(features_dae.shape[1],1) 
print(features_dae_1.shape)
print(features_dae_2.shape)
print(features_lab.shape)
# Out:
# (2, 10000)
# (10000, 1)
# (10000, 1)
# (10000, 1)

# %% [markdown]
# 将python的变量转化成R的变量，双百分号表示整个cell是R语法，-i表示从python中拿变量，-o表示输出为python变量（这里我用最基本的转化方式，（变量到变量）可以利用panda等，可以保存更好的数据结构。）

# %%
# %%R -i features_dae_1 -o features_dae_r1
# features_dae_r1 <- features_dae_1

# %%
# %%R -i features_dae_2 -o features_dae_r2
# features_dae_r2 <- features_dae_2

# %%
# %%R -i features_lab -o features_lab_r
# features_lab_r <- features_lab

# %%
# %%R -i features_dae -o features_dae_r
# features_dae_r <- features_dae

# %% [markdown]
# 将得到R变量画散点图

# %%
# %%R
# jiangwei<- data.frame(features_dae_r1,features_dae_r2)
# jiangwei$Class<- features_lab_r
# #查看种类个数为9，定义9种颜色
#
#
# #将降维后需要的结果转为数据框形式
#
# library(ggplot2)
#
# #将特征变量加入降维后的数据框
# ggplot(jiangwei, mapping=aes(x=features_dae_r1, y=features_dae_r2, color=Class)) +
#   geom_point(size=1.25) +
#   labs(title = "dae",
#        x = "x",
#        y = "y") +
#   theme(plot.title = element_text(hjust = 0.5))+
#   #geom_smooth(method="loess")+
#   theme_bw() +
#   theme(panel.border = element_blank(),panel.grid.major = element_blank())+
#   theme(panel.grid.minor = element_blank(),axis.line = element_line(colour = "black"))

# %% [markdown]
# ## SAE
#
# 首先，先建立一个全连接（dense）的编码器和解码器。参数e_dim=2表示中间的隐藏层是2维，,L1=0.001表示L1正则的权重。

# %%
from keras import optimizers
sparse_ae, sparse_en, sparse_de = dense_autoencoder(e_dim=2,L1=0.00001)
opt = optimizers.Adam(lr=0.01)
sparse_ae.compile(optimizer=opt, loss='binary_crossentropy')
sparse_ae.fit(x_train, x_train,
                nb_epoch=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# /home/ncclab/anaconda3/envs/iccv/lib/python3.7/site-packages/ipykernel_launcher.py:19: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# /home/ncclab/anaconda3/envs/iccv/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# /home/ncclab/anaconda3/envs/iccv/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# /home/ncclab/anaconda3/envs/iccv/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   if __name__ == '__main__':
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.4583 - val_loss: 0.3417
# Epoch 2/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.3104 - val_loss: 0.2913
# Epoch 3/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2831 - val_loss: 0.2771
# Epoch 4/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2739 - val_loss: 0.2711
# Epoch 5/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2697 - val_loss: 0.2682
# Epoch 6/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2675 - val_loss: 0.2665
# Epoch 7/50
# 60000/60000 [==============================] - 3s 53us/step - loss: 0.2662 - val_loss: 0.2654
# Epoch 8/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2653 - val_loss: 0.2647
# Epoch 9/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2647 - val_loss: 0.2642
# Epoch 10/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2643 - val_loss: 0.2639
# Epoch 11/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2640 - val_loss: 0.2636
# Epoch 12/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2638 - val_loss: 0.2634
# Epoch 13/50
# 60000/60000 [==============================] - 3s 53us/step - loss: 0.2636 - val_loss: 0.2632
# Epoch 14/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2635 - val_loss: 0.2631
# Epoch 15/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2633 - val_loss: 0.2630
# Epoch 16/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2633 - val_loss: 0.2630
# Epoch 17/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2632 - val_loss: 0.2629
# Epoch 18/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2631 - val_loss: 0.2628
# Epoch 19/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2631 - val_loss: 0.2628
# Epoch 20/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2630 - val_loss: 0.2627
# Epoch 21/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2630 - val_loss: 0.2627
# Epoch 22/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2630 - val_loss: 0.2627
# Epoch 23/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2630 - val_loss: 0.2627
# Epoch 24/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 25/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2629 - val_loss: 0.2627
# Epoch 26/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 27/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 28/50
# 60000/60000 [==============================] - 3s 53us/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 29/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 30/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 31/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 32/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 33/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2629 - val_loss: 0.2625
# Epoch 34/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 35/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 36/50
# 60000/60000 [==============================] - 3s 53us/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 37/50
# 60000/60000 [==============================] - 3s 53us/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 38/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2628 - val_loss: 0.2625
# Epoch 39/50
# 60000/60000 [==============================] - 3s 53us/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 40/50
# 60000/60000 [==============================] - 3s 53us/step - loss: 0.2628 - val_loss: 0.2625
# Epoch 41/50
# 60000/60000 [==============================] - 3s 52us/step - loss: 0.2628 - val_loss: 0.2625
# Epoch 42/50
# 60000/60000 [==============================] - 3s 52us/step - loss: 0.2628 - val_loss: 0.2625
# Epoch 43/50
# 60000/60000 [==============================] - 3s 52us/step - loss: 0.2628 - val_loss: 0.2625
# Epoch 44/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.2628 - val_loss: 0.2625
# Epoch 45/50
# 60000/60000 [==============================] - 3s 52us/step - loss: 0.2628 - val_loss: 0.2625
# Epoch 46/50
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.2628 - val_loss: 0.2625
# Epoch 47/50
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.2628 - val_loss: 0.2625
# Epoch 48/50
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.2628 - val_loss: 0.2625
# Epoch 49/50
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.2628 - val_loss: 0.2626
# Epoch 50/50
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.2628 - val_loss: 0.2625

# %%
import numpy as np
features_sae = sparse_en.predict(x_test[0:10000:1])

features_sae = np.transpose(features_sae,(1,0))
print(features_sae.shape)
features_sae_1 =  features_sae[0].reshape(features_sae.shape[1],1)
features_sae_2 =  features_sae[1].reshape(features_sae.shape[1],1)

print(features_sae_1.shape)
print(features_sae_2.shape)
# Out:
# (2, 10000)
# (10000, 1)
# (10000, 1)

# %%
# %%R -i features_sae_1 -o features_sae_r1
# features_sae_r1 <- features_sae_1

# %%
# %%R -i features_sae_2 -o features_sae_r2
# features_sae_r2 <- features_sae_2

# %%
# %%R
# jiangwei_sae<- data.frame(features_sae_r1,features_sae_r2)
# jiangwei_sae$Class<- features_lab_r
# #查看种类个数为9，定义9种颜色
#
#
# #将降维后需要的结果转为数据框形式
#
# library(ggplot2)
#
# #将特征变量加入降维后的数据框
# ggplot(jiangwei_sae, mapping=aes(x=features_sae_r1, y=features_sae_r2, color=Class)) +
#   geom_point(size=0.25) +
#   labs(title = "sae",
#        x = "x",
#        y = "y") +
#   theme(plot.title = element_text(hjust = 0.5))+
#   #geom_smooth(method="loess")+
#   theme_bw() +
#   theme(panel.border = element_blank(),panel.grid.major = element_blank())+
#   theme(panel.grid.minor = element_blank(),axis.line = element_line(colour = "black"))

# %% [markdown]
# ## t-SNE

# %% [markdown]
# 接下来对mnist数据集做t-SNE

# %%
from sklearn import manifold
from sklearn import decomposition
tsne = manifold.TSNE(n_components=2, init='pca',perplexity=50,early_exaggeration=3.0)
features_tsne  = tsne.fit_transform(x_test)

# %%
import numpy as np
print(features_tsne.shape)
features_tsne = np.transpose(features_tsne,(1,0))
features_tsne_1 =  features_tsne[0].reshape(features_tsne.shape[1],1)
features_tsne_2 =  features_tsne[1].reshape(features_tsne.shape[1],1)
print(features_tsne_1.shape)
print(features_tsne_2.shape)
print(features_lab.shape)
# Out:
# (10000, 2)
# (10000, 1)
# (10000, 1)
# (10000, 1)

# %%
# %%R -i features_tsne_1 -o features_tsne_r1
# features_tsne_r1 <- features_tsne_1

# %%
# %%R -i features_tsne_2 -o features_tsne_r2
# features_tsne_r2 <- features_tsne_2

# %%
# %%R
# tsne<- data.frame(features_tsne_r1,features_tsne_r2)
# tsne$Class_<- features_lab_r
# #查看种类个数为9，定义9种颜色
#
#
#
# #将降维后需要的结果转为数据框形式
#
# library(ggplot2)
#
# #将特征变量加入降维后的数据框
# ggplot(tsne, mapping=aes(x=features_tsne_r1, y=features_tsne_r2, color=Class_)) +
#   geom_point(size=1.25) +
#   labs(title = "t-SNE",
#        x = "x",
#        y = "y") +
#   theme(plot.title = element_text(hjust = 1.5))+
#   #geom_smooth(method="loess")+
#   theme_bw() +
#   theme(panel.border = element_blank(),panel.grid.major = element_blank())+
#   theme(panel.grid.minor = element_blank(),axis.line = element_line(colour = "black"))

# %% [markdown]
# ## PCA

# %% [markdown]
# 接下来对mnist数据集做t-SNE

# %%
pca = decomposition.PCA(n_components=2)
features_pca =pca.fit_transform(x_test)

# %%
import numpy as np
print(features_pca.shape)
features_pca = np.transpose(features_pca,(1,0))
features_pca_1 =  features_pca[0].reshape(features_pca.shape[1],1)
features_pca_2 =  features_pca[1].reshape(features_pca.shape[1],1)
print(features_pca_1.shape)
print(features_pca_2.shape)
print(features_lab.shape)
# Out:
# (10000, 2)
# (10000, 1)
# (10000, 1)
# (10000, 1)

# %%
# %%R -i features_pca_1 -o features_pca_r1
# features_pca_r1 <- features_pca_1

# %%
# %%R -i features_pca_2 -o features_pca_r2
# features_pca_r2 <- features_pca_2

# %%
# %%R
# tsne<- data.frame(features_pca_r1,features_pca_r2)
# tsne$Class<- features_lab_r
# #查看种类个数为9，定义9种颜色
#
#
#
# #将降维后需要的结果转为数据框形式
#
# library(ggplot2)
#
# #将特征变量加入降维后的数据框
# ggplot(tsne, mapping=aes(x=features_pca_r1, y=features_pca_r2, color=Class)) +
#   geom_point(size=1.25) +
#   labs(title = "pca",
#        x = "x",
#        y = "y") +
#   theme(plot.title = element_text(hjust = 0.5))+
#   #geom_smooth(method="loess")+
#   theme_bw() +
#   theme(panel.border = element_blank(),panel.grid.major = element_blank())+
#   theme(panel.grid.minor = element_blank(),axis.line = element_line(colour = "black"))
